# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-M-Elshazly/Homework-7/blob/main/Homework_7_Problem_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Homework 2
# #Problem2_VGG_Cifar10_dropout
# #Ahmed Elshazly
# #801420724

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from sklearn.metrics import confusion_matrix, f1_score
import time
from matplotlib import pyplot as plt
import numpy as np
import torch.nn.functional as F

# %%
# Set device
torch.cuda.empty_cache()
device1 = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# %%
# Load CIFAR-10 dataset to calculate mean and std
train_dataset = torchvision.datasets.CIFAR10('../data-unversioned/p1ch7/', train=True, download=True)
val_dataset = torchvision.datasets.CIFAR10('../data-unversioned/p1ch7/', train=False, download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
img, label = train_dataset[100]
img, label, class_names[label]
# Out:
# (<PIL.Image.Image image mode=RGB size=32x32>, 8, 'ship')

# %%
len(train_dataset)
# Out:
# 50000

# %%
plt.imshow(img)
plt.show()

# %%
from torchvision import transforms

to_tensor = transforms.ToTensor()
img_t = to_tensor(img)
img_t.shape
# Out:
# torch.Size([3, 32, 32])

# %%
train_dataset = torchvision.datasets.CIFAR10('../data-unversioned/p1ch7/', train=True, download=False,
                          transform=transforms.ToTensor())
imgs = torch.stack([img_t for img_t, _ in train_dataset], dim=3)
imgs.shape
# Out:
# torch.Size([3, 32, 32, 50000])

# %%
plt.imshow(img_t.permute(1, 2, 0))  # <1>
plt.show()

# %%
train_mean=imgs.view(3, -1).mean(dim=1)
train_std=imgs.view(3, -1).std(dim=1)
print(train_mean)
print(train_std)
# Out:
# tensor([0.4914, 0.4822, 0.4465])
# tensor([0.2470, 0.2435, 0.2616])

# %%
transforms.Normalize(train_mean, train_std)
# Out:
# Normalize(mean=tensor([0.4914, 0.4822, 0.4465]), std=tensor([0.2470, 0.2435, 0.2616]))

# %%
transformed_train_dataset = torchvision.datasets.CIFAR10(
    '../data-unversioned/p1ch7/', train=True, download=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(train_mean,
                             train_std)
    ]))
train_loader = torch.utils.data.DataLoader(transformed_train_dataset, batch_size=128, shuffle=True)

# %%
import torch
import torch.nn as nn

class VGG(nn.Module):
    def __init__(self, num_classes=10):
        super(VGG, self).__init__()
        layers = []
        in_channels = 3
        cfg = [64, 'M', 128, 'M', 256, 256, 'M']

        for v in cfg:
            if v == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=1)
                layers += [conv2d,
                           nn.BatchNorm2d(v),
                           nn.ReLU(inplace=True),
                           nn.Dropout(p=0.5)]
                in_channels = v

        self.features = nn.Sequential(*layers)

        self.classifier = nn.Sequential(
            nn.Linear(256 * 4 * 4, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(512, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x


model = VGG(num_classes=10).to(device1)

# %%
val_dataset = torchvision.datasets.CIFAR10('../data-unversioned/p1ch7/', train=False, download=False,
                          transform=transforms.ToTensor())

# %%
imgs = torch.stack([img_t for img_t, _ in val_dataset], dim=3)
imgs.shape
# Out:
# torch.Size([3, 32, 32, 10000])

# %%
val_mean=imgs.view(3, -1).mean(dim=1)
val_std=imgs.view(3, -1).std(dim=1)
print(val_mean)
print(val_std)
# Out:
# tensor([0.4942, 0.4851, 0.4504])
# tensor([0.2467, 0.2429, 0.2616])

# %%
transforms.Normalize(val_mean, val_std)
# Out:
# Normalize(mean=tensor([0.4942, 0.4851, 0.4504]), std=tensor([0.2467, 0.2429, 0.2616]))

# %%
transformed_val_dataset = torchvision.datasets.CIFAR10(
    '../data-unversioned/p1ch7/', train=False, download=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(train_mean,
                             train_std)
    ]))
val_loader = torch.utils.data.DataLoader(transformed_val_dataset, batch_size=128, shuffle=False)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)
num_epochs = 100
total_start_time = time.time()
losses=[]
val_losses=[]
train_accs=[]
val_accs=[]
tr_correct=0
tr_total=0
val_correct=0
val_total=0

for epoch in range(num_epochs):
    start_time = time.time()
    counter=0
    cum_loss=0
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device1), labels.to(device1)
        batch_size=imgs.shape[0]
        outputs=model(imgs)
        loss = loss_fn(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        outputs=model(imgs)
        _,predicted=torch.max(outputs,dim=1)
        tr_total+=labels.shape[0]
        tr_correct+=int((predicted==labels).sum())
        counter+=1
        cum_loss+=loss

    tr_acc=tr_correct/tr_total
    epoch_loss=cum_loss/counter

    counter_val=0
    cum_loss_val=0
    for imgs, labels in val_loader:
      imgs, labels = imgs.to(device1), labels.to(device1)
      batch_size=imgs.shape[0]
      with torch.no_grad():
        outputs = model(imgs)
        val_loss = loss_fn(outputs, labels)
      _,predicted=torch.max(outputs,dim=1)
      val_total+=labels.shape[0]
      val_correct+=int((predicted==labels).sum())
      counter_val+=1
      cum_loss_val+=val_loss

    val_acc=val_correct/val_total
    epoch_val_loss=cum_loss_val/counter_val



    end_time = time.time()
    training_time = end_time - start_time
    print(f"Epoch: {epoch+1}, Train Loss: {float(epoch_loss):.6f}, Val_Loss:{float(epoch_val_loss):.6f}, Runtime: {training_time:.2f} seconds, Train Accurracy : {float(tr_acc):.6f}, Validation Accuracy : {float(val_acc):.6f}")
    losses.append(float(epoch_loss))
    val_losses.append(float(epoch_val_loss))
    train_accs.append(float(tr_acc))
    val_accs.append(float(val_acc))

total_end_time = time.time()
total_training_time = total_end_time - total_start_time
print(f'Total Training Time: {total_training_time:.2f} seconds')
plt.figure(figsize=(10, 6))
plt.plot(range(num_epochs), losses, marker='o', linestyle='-', color='b',label='Train Loss')
plt.plot(range(num_epochs), val_losses, marker='o', linestyle='-', color='r', label='Validation Loss')
plt.title("Loss vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()


# Plotting train accur vs. epochs
plt.figure(figsize=(10, 6))
plt.plot(range(num_epochs), train_accs, marker='o', linestyle='-', color='b',label='Train Accuracy')
plt.plot(range(num_epochs), val_accs, marker='o', linestyle='-', color='r',label='Validation Accuracy')
plt.title(" Accuracy vs Epochs")
plt.xlabel("Epochs")
plt.ylabel(" Accuracy")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch: 1, Train Loss: 1.930035, Val_Loss:1.707318, Runtime: 11.85 seconds, Train Accurracy : 0.290740, Validation Accuracy : 0.362600
# Epoch: 2, Train Loss: 1.615127, Val_Loss:1.541912, Runtime: 11.87 seconds, Train Accurracy : 0.351540, Validation Accuracy : 0.394300
# Epoch: 3, Train Loss: 1.476810, Val_Loss:1.428655, Runtime: 11.88 seconds, Train Accurracy : 0.390860, Validation Accuracy : 0.421867
# Epoch: 4, Train Loss: 1.385457, Val_Loss:1.378194, Runtime: 11.85 seconds, Train Accurracy : 0.420390, Validation Accuracy : 0.441400
# Epoch: 5, Train Loss: 1.315277, Val_Loss:1.316297, Runtime: 11.89 seconds, Train Accurracy : 0.444496, Validation Accuracy : 0.458200
# Epoch: 6, Train Loss: 1.252816, Val_Loss:1.243218, Runtime: 11.91 seconds, Train Accurracy : 0.464830, Validation Accuracy : 0.475100
# Epoch: 7, Train Loss: 1.201975, Val_Loss:1.205317, Runtime: 11.94 seconds, Train Accurracy : 0.482969, Validation Accuracy : 0.489129
# Epoch: 8, Train Loss: 1.150697, Val_Loss:1.155032, Runtime: 11.86 seconds, Train Accurracy : 0.499185, Validation Accuracy : 0.502112
# Epoch: 9, Train Loss: 1.114176, Val_Loss:1.136036, Runtime: 11.86 seconds, Train Accurracy : 0.513324, Validation Accuracy : 0.512133
# Epoch: 10, Train Loss: 1.073782, Val_Loss:1.105127, Runtime: 11.87 seconds, Train Accurracy : 0.526054, Validation Accuracy : 0.521650
# Epoch: 11, Train Loss: 1.038073, Val_Loss:1.077114, Runtime: 11.88 seconds, Train Accurracy : 0.537847, Validation Accuracy : 0.530600
# Epoch: 12, Train Loss: 1.006628, Val_Loss:1.036691, Runtime: 11.85 seconds, Train Accurracy : 0.548598, Validation Accuracy : 0.539808
# Epoch: 13, Train Loss: 0.981830, Val_Loss:1.009969, Runtime: 11.81 seconds, Train Accurracy : 0.558574, Validation Accuracy : 0.548515
# Epoch: 14, Train Loss: 0.962763, Val_Loss:0.994779, Runtime: 11.81 seconds, Train Accurracy : 0.567673, Validation Accuracy : 0.556093
# Epoch: 15, Train Loss: 0.929366, Val_Loss:0.994838, Runtime: 11.81 seconds, Train Accurracy : 0.576348, Validation Accuracy : 0.562787
# Epoch: 16, Train Loss: 0.908823, Val_Loss:0.945819, Runtime: 11.82 seconds, Train Accurracy : 0.584058, Validation Accuracy : 0.569800
# Epoch: 17, Train Loss: 0.896218, Val_Loss:0.943733, Runtime: 11.80 seconds, Train Accurracy : 0.591421, Validation Accuracy : 0.576265
# Epoch: 18, Train Loss: 0.878061, Val_Loss:0.925463, Runtime: 11.82 seconds, Train Accurracy : 0.598281, Validation Accuracy : 0.582317
# Epoch: 83, Train Loss: 0.468142, Val_Loss:0.660129, Runtime: 11.81 seconds, Train Accurracy : 0.761853, Validation Accuracy : 0.713846
# Epoch: 84, Train Loss: 0.462798, Val_Loss:0.663829, Runtime: 11.79 seconds, Train Accurracy : 0.762990, Validation Accuracy : 0.714673
# Epoch: 85, Train Loss: 0.460474, Val_Loss:0.657317, Runtime: 11.82 seconds, Train Accurracy : 0.764130, Validation Accuracy : 0.715568
# Epoch: 86, Train Loss: 0.452681, Val_Loss:0.674593, Runtime: 11.80 seconds, Train Accurracy : 0.765229, Validation Accuracy : 0.716347
# Epoch: 87, Train Loss: 0.453500, Val_Loss:0.667823, Runtime: 11.80 seconds, Train Accurracy : 0.766299, Validation Accuracy : 0.717070
# Epoch: 88, Train Loss: 0.454638, Val_Loss:0.671097, Runtime: 11.80 seconds, Train Accurracy : 0.767368, Validation Accuracy : 0.717781
# Epoch: 89, Train Loss: 0.451442, Val_Loss:0.656358, Runtime: 11.79 seconds, Train Accurracy : 0.768418, Validation Accuracy : 0.718543
# Epoch: 90, Train Loss: 0.447264, Val_Loss:0.650115, Runtime: 11.78 seconds, Train Accurracy : 0.769452, Validation Accuracy : 0.719320
# Epoch: 91, Train Loss: 0.439892, Val_Loss:0.669443, Runtime: 11.81 seconds, Train Accurracy : 0.770478, Validation Accuracy : 0.720055
# Epoch: 92, Train Loss: 0.442630, Val_Loss:0.658362, Runtime: 11.81 seconds, Train Accurracy : 0.771491, Validation Accuracy : 0.720823
# Epoch: 93, Train Loss: 0.439690, Val_Loss:0.662410, Runtime: 11.81 seconds, Train Accurracy : 0.772506, Validation Accuracy : 0.721541
# Epoch: 94, Train Loss: 0.434415, Val_Loss:0.644120, Runtime: 11.81 seconds, Train Accurracy : 0.773493, Validation Accuracy : 0.722296
# Epoch: 95, Train Loss: 0.435098, Val_Loss:0.649017, Runtime: 11.82 seconds, Train Accurracy : 0.774472, Validation Accuracy : 0.722989
# Epoch: 96, Train Loss: 0.427612, Val_Loss:0.669782, Runtime: 11.81 seconds, Train Accurracy : 0.775428, Validation Accuracy : 0.723656
# Epoch: 97, Train Loss: 0.431882, Val_Loss:0.646914, Runtime: 11.80 seconds, Train Accurracy : 0.776380, Validation Accuracy : 0.724316
# Epoch: 98, Train Loss: 0.421882, Val_Loss:0.657695, Runtime: 11.79 seconds, Train Accurracy : 0.777329, Validation Accuracy : 0.724932
# Epoch: 99, Train Loss: 0.419171, Val_Loss:0.655114, Runtime: 11.81 seconds, Train Accurracy : 0.778277, Validation Accuracy : 0.725608
# Epoch: 100, Train Loss: 0.416163, Val_Loss:0.654047, Runtime: 11.79 seconds, Train Accurracy : 0.779203, Validation Accuracy : 0.726268
# Total Training Time: 1181.60 seconds

# %%
def get_model_size(model):
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total_params, trainable_params

# %%
total_params, trainable_params = get_model_size(model)
print(f"  Total parameters: {total_params}")
print(f"  Trainable parameters: {trainable_params}")
# Out:
#   Total parameters: 3128202
#   Trainable parameters: 3128202

# %%
torch.save(model, "saved_model.pth")
print("Full model saved as 'saved_model.pth'")


torch.save(model.state_dict(), "saved_weights.pth")
print("Model weights saved as 'saved_weights.pth'")
# Out:
# Full model saved as 'saved_model.pth'
# Model weights saved as 'saved_weights.pth'
