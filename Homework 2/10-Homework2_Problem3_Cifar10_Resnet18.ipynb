# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-M-Elshazly/Homework-7/blob/main/Homework_7_Problem_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Homework 2
# #Problem3_Cifar10_Resnet18
# #Ahmed Elshazly
# #801420724

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from sklearn.metrics import confusion_matrix, f1_score
import time
from matplotlib import pyplot as plt
import numpy as np
import torch.nn.functional as F

# %%
# Set device
device1 = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# %%
# Load CIFAR-10 dataset to calculate mean and std
train_dataset = torchvision.datasets.CIFAR10('../data-unversioned/p1ch7/', train=True, download=True)
val_dataset = torchvision.datasets.CIFAR10('../data-unversioned/p1ch7/', train=False, download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
img, label = train_dataset[100]
img, label, class_names[label]
# Out:
# (<PIL.Image.Image image mode=RGB size=32x32>, 8, 'ship')

# %%
len(train_dataset)
# Out:
# 50000

# %%
plt.imshow(img)
plt.show()

# %%
from torchvision import transforms

to_tensor = transforms.ToTensor()
img_t = to_tensor(img)
img_t.shape
# Out:
# torch.Size([3, 32, 32])

# %%
train_dataset = torchvision.datasets.CIFAR10('../data-unversioned/p1ch7/', train=True, download=False,
                          transform=transforms.ToTensor())
imgs = torch.stack([img_t for img_t, _ in train_dataset], dim=3)
imgs.shape
# Out:
# torch.Size([3, 32, 32, 50000])

# %%
plt.imshow(img_t.permute(1, 2, 0))  # <1>
plt.show()

# %%
train_mean=imgs.view(3, -1).mean(dim=1)
train_std=imgs.view(3, -1).std(dim=1)
print(train_mean)
print(train_std)
# Out:
# tensor([0.4914, 0.4822, 0.4465])
# tensor([0.2470, 0.2435, 0.2616])

# %%
transforms.Normalize(train_mean, train_std)
# Out:
# Normalize(mean=tensor([0.4914, 0.4822, 0.4465]), std=tensor([0.2470, 0.2435, 0.2616]))

# %%
transformed_train_dataset = torchvision.datasets.CIFAR10(
    '../data-unversioned/p1ch7/', train=True, download=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(train_mean,
                             train_std)
    ]))
train_loader = torch.utils.data.DataLoader(transformed_train_dataset, batch_size=128, shuffle=True)

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)


        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)


        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != self.expansion * out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, self.expansion * out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * out_channels)
            )

    def forward(self, x):

        out = F.relu(self.bn1(self.conv1(x)))

        out = self.bn2(self.conv2(out))

        out += self.shortcut(x)

        out = F.relu(out)
        return out

class ResNet18(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet18, self).__init__()
        self.in_channels = 64


        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)


        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 64, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 128, num_blocks[3], stride=1)
        self.layer5 = self._make_layer(block, 256, num_blocks[4], stride=1)
        self.layer6 = self._make_layer(block, 256, num_blocks[5], stride=1)
        self.layer7 = self._make_layer(block, 512, num_blocks[6], stride=1)
        self.layer8 = self._make_layer(block, 512, num_blocks[7], stride=1)


        self.linear = nn.Linear(512 * 4*4, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):

        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):

        out=F.max_pool2d(F.relu(self.bn1(self.conv1(x))), 2)

        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = self.layer6(out)
        out = self.layer7(out)
        out = self.layer8(out)

        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out




model = ResNet18(BasicBlock, [1, 1, 1, 1,1,1,1,1], num_classes=10).to(device1)

# %%
val_dataset = torchvision.datasets.CIFAR10('../data-unversioned/p1ch7/', train=False, download=False,
                          transform=transforms.ToTensor())

# %%
imgs = torch.stack([img_t for img_t, _ in val_dataset], dim=3)
imgs.shape
# Out:
# torch.Size([3, 32, 32, 10000])

# %%
val_mean=imgs.view(3, -1).mean(dim=1)
val_std=imgs.view(3, -1).std(dim=1)
print(val_mean)
print(val_std)
# Out:
# tensor([0.4942, 0.4851, 0.4504])
# tensor([0.2467, 0.2429, 0.2616])

# %%
transforms.Normalize(val_mean, val_std)
# Out:
# Normalize(mean=tensor([0.4942, 0.4851, 0.4504]), std=tensor([0.2467, 0.2429, 0.2616]))

# %%
transformed_val_dataset = torchvision.datasets.CIFAR10(
    '../data-unversioned/p1ch7/', train=False, download=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(train_mean,
                             train_std)
    ]))
val_loader = torch.utils.data.DataLoader(transformed_val_dataset, batch_size=128, shuffle=False)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)
num_epochs = 20
total_start_time = time.time()
losses=[]
val_losses=[]
train_accs=[]
val_accs=[]
tr_correct=0
tr_total=0
val_correct=0
val_total=0

for epoch in range(num_epochs):
    start_time = time.time()
    counter=0
    cum_loss=0
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device1), labels.to(device1)
        batch_size=imgs.shape[0]
        outputs=model(imgs)
        loss = loss_fn(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        outputs=model(imgs)
        _,predicted=torch.max(outputs,dim=1)
        tr_total+=labels.shape[0]
        tr_correct+=int((predicted==labels).sum())
        counter+=1
        cum_loss+=loss

    tr_acc=tr_correct/tr_total
    epoch_loss=cum_loss/counter

    counter_val=0
    cum_loss_val=0
    for imgs, labels in val_loader:
      imgs, labels = imgs.to(device1), labels.to(device1)
      batch_size=imgs.shape[0]
      with torch.no_grad():
        outputs = model(imgs)
        val_loss = loss_fn(outputs, labels)
      _,predicted=torch.max(outputs,dim=1)
      val_total+=labels.shape[0]
      val_correct+=int((predicted==labels).sum())
      counter_val+=1
      cum_loss_val+=val_loss

    val_acc=val_correct/val_total
    epoch_val_loss=cum_loss_val/counter_val



    end_time = time.time()
    training_time = end_time - start_time
    print(f"Epoch: {epoch+1}, Train Loss: {float(epoch_loss):.6f}, Val_Loss:{float(epoch_val_loss):.6f}, Runtime: {training_time:.2f} seconds, Train Accurracy : {float(tr_acc):.6f}, Validation Accuracy : {float(val_acc):.6f}")
    losses.append(float(epoch_loss))
    val_losses.append(float(epoch_val_loss))
    train_accs.append(float(tr_acc))
    val_accs.append(float(val_acc))

total_end_time = time.time()
total_training_time = total_end_time - total_start_time
print(f'Total Training Time: {total_training_time:.2f} seconds')
plt.figure(figsize=(10, 6))
plt.plot(range(num_epochs), losses, marker='o', linestyle='-', color='b',label='Train Loss')
plt.plot(range(num_epochs), val_losses, marker='o', linestyle='-', color='r', label='Validation Loss')
plt.title("Loss vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()


# Plotting train accur vs. epochs
plt.figure(figsize=(10, 6))
plt.plot(range(num_epochs), train_accs, marker='o', linestyle='-', color='b',label='Train Accuracy')
plt.plot(range(num_epochs), val_accs, marker='o', linestyle='-', color='r',label='Validation Accuracy')
plt.title(" Accuracy vs Epochs")
plt.xlabel("Epochs")
plt.ylabel(" Accuracy")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch: 1, Train Loss: 1.479985, Val_Loss:1.423698, Runtime: 57.64 seconds, Train Accurracy : 0.670840, Validation Accuracy : 0.511600
# Epoch: 2, Train Loss: 0.931599, Val_Loss:0.900555, Runtime: 57.93 seconds, Train Accurracy : 0.769430, Validation Accuracy : 0.599700
# Epoch: 3, Train Loss: 0.730187, Val_Loss:0.840954, Runtime: 57.97 seconds, Train Accurracy : 0.823500, Validation Accuracy : 0.639133
# Epoch: 4, Train Loss: 0.598918, Val_Loss:0.808508, Runtime: 58.02 seconds, Train Accurracy : 0.859070, Validation Accuracy : 0.660825
# Epoch: 5, Train Loss: 0.500288, Val_Loss:0.881489, Runtime: 57.93 seconds, Train Accurracy : 0.883892, Validation Accuracy : 0.670300
# Epoch: 6, Train Loss: 0.418969, Val_Loss:0.651609, Runtime: 57.86 seconds, Train Accurracy : 0.901877, Validation Accuracy : 0.689467
# Epoch: 7, Train Loss: 0.333009, Val_Loss:0.997841, Runtime: 57.62 seconds, Train Accurracy : 0.915466, Validation Accuracy : 0.691800
# Epoch: 8, Train Loss: 0.270289, Val_Loss:0.591034, Runtime: 57.40 seconds, Train Accurracy : 0.925780, Validation Accuracy : 0.707675
# Epoch: 9, Train Loss: 0.209302, Val_Loss:0.964994, Runtime: 57.32 seconds, Train Accurracy : 0.933904, Validation Accuracy : 0.711411
# Epoch: 10, Train Loss: 0.155543, Val_Loss:0.667458, Runtime: 57.30 seconds, Train Accurracy : 0.940478, Validation Accuracy : 0.721580
# Epoch: 11, Train Loss: 0.110342, Val_Loss:0.694390, Runtime: 57.32 seconds, Train Accurracy : 0.945867, Validation Accuracy : 0.729291
# Epoch: 12, Train Loss: 0.068119, Val_Loss:0.893613, Runtime: 57.33 seconds, Train Accurracy : 0.950365, Validation Accuracy : 0.733492
# Epoch: 13, Train Loss: 0.046628, Val_Loss:0.820306, Runtime: 57.33 seconds, Train Accurracy : 0.954172, Validation Accuracy : 0.738592
# Epoch: 14, Train Loss: 0.031114, Val_Loss:0.660064, Runtime: 57.35 seconds, Train Accurracy : 0.957446, Validation Accuracy : 0.745550
# Epoch: 15, Train Loss: 0.012499, Val_Loss:0.618445, Runtime: 57.34 seconds, Train Accurracy : 0.960281, Validation Accuracy : 0.752373
# Epoch: 16, Train Loss: 0.005432, Val_Loss:0.636120, Runtime: 57.32 seconds, Train Accurracy : 0.962764, Validation Accuracy : 0.758500
# Epoch: 17, Train Loss: 0.002783, Val_Loss:0.629881, Runtime: 57.32 seconds, Train Accurracy : 0.964954, Validation Accuracy : 0.764147
# Epoch: 18, Train Loss: 0.001494, Val_Loss:0.636996, Runtime: 57.35 seconds, Train Accurracy : 0.966900, Validation Accuracy : 0.769356
# Epoch: 19, Train Loss: 0.001890, Val_Loss:0.646638, Runtime: 57.38 seconds, Train Accurracy : 0.968641, Validation Accuracy : 0.773995
# Epoch: 20, Train Loss: 0.001121, Val_Loss:0.678847, Runtime: 57.43 seconds, Train Accurracy : 0.970209, Validation Accuracy : 0.778025
# Total Training Time: 1150.48 seconds

# %%
def get_model_size(model):
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total_params, trainable_params

# %%
total_params, trainable_params = get_model_size(model)
print(f"  Total parameters: {total_params}")
print(f"  Trainable parameters: {trainable_params}")
# Out:
#   Total parameters: 11250762
#   Trainable parameters: 11250762

# %%
torch.save(model, "saved_model.pth")
print("Full model saved as 'saved_model.pth'")


torch.save(model.state_dict(), "saved_weights.pth")
print("Model weights saved as 'saved_weights.pth'")
# Out:
# Full model saved as 'saved_model.pth'
# Model weights saved as 'saved_weights.pth'
