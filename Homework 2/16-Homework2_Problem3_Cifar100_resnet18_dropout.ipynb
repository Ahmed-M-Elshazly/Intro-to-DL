# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-M-Elshazly/Homework-7/blob/main/Homework_7_Problem_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Homework 2
# #Cifar100_resnet18_dropout
# #Ahmed Elshazly
# #801420724

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from sklearn.metrics import confusion_matrix, f1_score
import time
from matplotlib import pyplot as plt
import numpy as np
import torch.nn.functional as F

# %%
# Set device
torch.cuda.empty_cache()
device1 = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# %%
# Load CIFAR-10 dataset to calculate mean and std
train_dataset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True)
val_dataset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
len(val_dataset)
# Out:
# 10000

# %%
img, label = train_dataset[100]

# %%
plt.imshow(img)
plt.show()

# %%
from torchvision import transforms

to_tensor = transforms.ToTensor()
img_t = to_tensor(img)
img_t.shape
# Out:
# torch.Size([3, 32, 32])

# %%
train_dataset = torchvision.datasets.CIFAR100(root='./data', train=True, download=False,
                          transform=transforms.ToTensor())
imgs = torch.stack([img_t for img_t, _ in train_dataset], dim=3)
imgs.shape
# Out:
# torch.Size([3, 32, 32, 50000])

# %%
plt.imshow(img_t.permute(1, 2, 0))
plt.show()

# %%
train_mean=imgs.view(3, -1).mean(dim=1)
train_std=imgs.view(3, -1).std(dim=1)
print(train_mean)
print(train_std)
# Out:
# tensor([0.5071, 0.4865, 0.4409])
# tensor([0.2673, 0.2564, 0.2762])

# %%
transforms.Normalize(train_mean, train_std)
# Out:
# Normalize(mean=tensor([0.5071, 0.4865, 0.4409]), std=tensor([0.2673, 0.2564, 0.2762]))

# %%
transformed_train_dataset = torchvision.datasets.CIFAR100(root='./data', train=True, download=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(train_mean,
                             train_std)
    ]))
train_loader = torch.utils.data.DataLoader(transformed_train_dataset, batch_size=128, shuffle=True)

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.dropout1 = nn.Dropout(p=0.5)



        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)



        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != self.expansion * out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, self.expansion * out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * out_channels)
            )

    def forward(self, x):

        out = F.relu(self.bn1(self.conv1(x)))
        out= self.dropout1(out)

        out = self.bn2(self.conv2(out))

        out += self.shortcut(x)

        out = F.relu(out)

        return out

class ResNet18(nn.Module):
    def __init__(self, block, num_blocks, num_classes=100):
        super(ResNet18, self).__init__()
        self.in_channels = 64


        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)


        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 64, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 128, num_blocks[3], stride=1)
        self.layer5 = self._make_layer(block, 256, num_blocks[4], stride=1)
        self.layer6 = self._make_layer(block, 256, num_blocks[5], stride=1)
        self.layer7 = self._make_layer(block, 512, num_blocks[6], stride=1)
        self.layer8 = self._make_layer(block, 512, num_blocks[7], stride=1)


        self.linear = nn.Linear(512 * 4*4, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):

        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):

        out=F.max_pool2d(F.relu(self.bn1(self.conv1(x))), 2)

        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = self.layer6(out)
        out = self.layer7(out)
        out = self.layer8(out)

        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out




model = ResNet18(BasicBlock, [1, 1, 1, 1,1,1,1,1], num_classes=100).to(device1)

# %%
val_dataset = torchvision.datasets.CIFAR100(root='./data', train=False, download=False,
                          transform=transforms.ToTensor())

# %%
imgs = torch.stack([img_t for img_t, _ in val_dataset], dim=3)
imgs.shape
# Out:
# torch.Size([3, 32, 32, 10000])

# %%
val_mean=imgs.view(3, -1).mean(dim=1)
val_std=imgs.view(3, -1).std(dim=1)
print(val_mean)
print(val_std)
# Out:
# tensor([0.5088, 0.4874, 0.4419])
# tensor([0.2683, 0.2574, 0.2771])

# %%
transforms.Normalize(val_mean, val_std)
# Out:
# Normalize(mean=tensor([0.5088, 0.4874, 0.4419]), std=tensor([0.2683, 0.2574, 0.2771]))

# %%
transformed_val_dataset = torchvision.datasets.CIFAR100(root='./data', train=False, download=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(train_mean,
                             train_std)
    ]))
val_loader = torch.utils.data.DataLoader(transformed_val_dataset, batch_size=128, shuffle=False)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)
num_epochs = 30
total_start_time = time.time()
losses=[]
val_losses=[]
train_accs=[]
val_accs=[]
tr_correct=0
tr_total=0
val_correct=0
val_total=0

for epoch in range(num_epochs):
    start_time = time.time()
    counter=0
    cum_loss=0
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device1), labels.to(device1)
        batch_size=imgs.shape[0]
        outputs=model(imgs)
        loss = loss_fn(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        outputs=model(imgs)
        _,predicted=torch.max(outputs,dim=1)
        tr_total+=labels.shape[0]
        tr_correct+=int((predicted==labels).sum())
        counter+=1
        cum_loss+=loss

    tr_acc=tr_correct/tr_total
    epoch_loss=cum_loss/counter

    counter_val=0
    cum_loss_val=0
    for imgs, labels in val_loader:
      imgs, labels = imgs.to(device1), labels.to(device1)
      batch_size=imgs.shape[0]
      with torch.no_grad():
        outputs = model(imgs)
        val_loss = loss_fn(outputs, labels)
      _,predicted=torch.max(outputs,dim=1)
      val_total+=labels.shape[0]
      val_correct+=int((predicted==labels).sum())
      counter_val+=1
      cum_loss_val+=val_loss

    val_acc=val_correct/val_total
    epoch_val_loss=cum_loss_val/counter_val



    end_time = time.time()
    training_time = end_time - start_time
    print(f"Epoch: {epoch+1}, Train Loss: {float(epoch_loss):.6f}, Val_Loss:{float(epoch_val_loss):.6f}, Runtime: {training_time:.2f} seconds, Train Accurracy : {float(tr_acc):.6f}, Validation Accuracy : {float(val_acc):.6f}")
    losses.append(float(epoch_loss))
    val_losses.append(float(epoch_val_loss))
    train_accs.append(float(tr_acc))
    val_accs.append(float(val_acc))

total_end_time = time.time()
total_training_time = total_end_time - total_start_time
print(f'Total Training Time: {total_training_time:.2f} seconds')
plt.figure(figsize=(10, 6))
plt.plot(range(num_epochs), losses, marker='o', linestyle='-', color='b',label='Train Loss')
plt.plot(range(num_epochs), val_losses, marker='o', linestyle='-', color='r', label='Validation Loss')
plt.title("Loss vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()


# Plotting train accur vs. epochs
plt.figure(figsize=(10, 6))
plt.plot(range(num_epochs), train_accs, marker='o', linestyle='-', color='b',label='Train Accuracy')
plt.plot(range(num_epochs), val_accs, marker='o', linestyle='-', color='r',label='Validation Accuracy')
plt.title(" Accuracy vs Epochs")
plt.xlabel("Epochs")
plt.ylabel(" Accuracy")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch: 1, Train Loss: 4.126863, Val_Loss:3.749904, Runtime: 61.92 seconds, Train Accurracy : 0.170240, Validation Accuracy : 0.126700
# Epoch: 2, Train Loss: 3.340070, Val_Loss:3.188017, Runtime: 62.00 seconds, Train Accurracy : 0.254980, Validation Accuracy : 0.175450
# Epoch: 3, Train Loss: 2.991287, Val_Loss:2.980039, Runtime: 62.04 seconds, Train Accurracy : 0.310293, Validation Accuracy : 0.204300
# Epoch: 4, Train Loss: 2.727709, Val_Loss:2.802810, Runtime: 62.11 seconds, Train Accurracy : 0.352310, Validation Accuracy : 0.227550
# Epoch: 5, Train Loss: 2.533926, Val_Loss:2.695975, Runtime: 62.13 seconds, Train Accurracy : 0.386716, Validation Accuracy : 0.246860
# Epoch: 6, Train Loss: 2.361520, Val_Loss:2.528163, Runtime: 62.16 seconds, Train Accurracy : 0.416717, Validation Accuracy : 0.265050
# Epoch: 7, Train Loss: 2.223422, Val_Loss:2.510643, Runtime: 62.20 seconds, Train Accurracy : 0.442817, Validation Accuracy : 0.278886
# Epoch: 8, Train Loss: 2.099824, Val_Loss:2.360461, Runtime: 62.20 seconds, Train Accurracy : 0.466010, Validation Accuracy : 0.292475
# Epoch: 9, Train Loss: 1.996855, Val_Loss:2.306938, Runtime: 62.29 seconds, Train Accurracy : 0.487020, Validation Accuracy : 0.305611
# Epoch: 10, Train Loss: 1.896962, Val_Loss:2.270369, Runtime: 62.32 seconds, Train Accurracy : 0.506044, Validation Accuracy : 0.316730
# Epoch: 11, Train Loss: 1.807901, Val_Loss:2.185448, Runtime: 62.36 seconds, Train Accurracy : 0.523611, Validation Accuracy : 0.327736
# Epoch: 12, Train Loss: 1.723650, Val_Loss:2.221120, Runtime: 62.35 seconds, Train Accurracy : 0.539970, Validation Accuracy : 0.336892
# Epoch: 13, Train Loss: 1.645417, Val_Loss:2.161544, Runtime: 62.33 seconds, Train Accurracy : 0.555451, Validation Accuracy : 0.345323
# Epoch: 14, Train Loss: 1.569157, Val_Loss:2.175935, Runtime: 62.32 seconds, Train Accurracy : 0.569973, Validation Accuracy : 0.352957
# Epoch: 15, Train Loss: 1.501267, Val_Loss:2.053471, Runtime: 62.25 seconds, Train Accurracy : 0.583841, Validation Accuracy : 0.361000
# Epoch: 16, Train Loss: 1.431425, Val_Loss:2.082590, Runtime: 62.28 seconds, Train Accurracy : 0.596874, Validation Accuracy : 0.367700
# Epoch: 17, Train Loss: 1.365545, Val_Loss:2.011942, Runtime: 62.18 seconds, Train Accurracy : 0.609362, Validation Accuracy : 0.374900
# Epoch: 18, Train Loss: 1.307288, Val_Loss:2.177393, Runtime: 62.21 seconds, Train Accurracy : 0.621129, Validation Accuracy : 0.379594
# Epoch: 19, Train Loss: 1.244626, Val_Loss:2.049916, Runtime: 62.17 seconds, Train Accurracy : 0.632409, Validation Accuracy : 0.384989
# Epoch: 20, Train Loss: 1.186790, Val_Loss:2.028167, Runtime: 62.19 seconds, Train Accurracy : 0.643347, Validation Accuracy : 0.390250
# Epoch: 21, Train Loss: 1.128532, Val_Loss:1.993302, Runtime: 62.12 seconds, Train Accurracy : 0.653809, Validation Accuracy : 0.395419
# Epoch: 22, Train Loss: 1.081191, Val_Loss:2.010299, Runtime: 62.14 seconds, Train Accurracy : 0.663873, Validation Accuracy : 0.400200
# Epoch: 23, Train Loss: 1.026915, Val_Loss:2.046381, Runtime: 62.09 seconds, Train Accurracy : 0.673503, Validation Accuracy : 0.404226
# Epoch: 24, Train Loss: 0.974708, Val_Loss:1.965397, Runtime: 62.05 seconds, Train Accurracy : 0.682788, Validation Accuracy : 0.408683
# Epoch: 25, Train Loss: 0.927304, Val_Loss:2.028466, Runtime: 62.07 seconds, Train Accurracy : 0.691760, Validation Accuracy : 0.412392
# Epoch: 26, Train Loss: 0.877202, Val_Loss:1.967401, Runtime: 62.09 seconds, Train Accurracy : 0.700347, Validation Accuracy : 0.416373
# Epoch: 27, Train Loss: 0.834010, Val_Loss:1.963196, Runtime: 62.06 seconds, Train Accurracy : 0.708606, Validation Accuracy : 0.420263
# Epoch: 28, Train Loss: 0.790664, Val_Loss:1.977823, Runtime: 62.04 seconds, Train Accurracy : 0.716482, Validation Accuracy : 0.423832
# Epoch: 29, Train Loss: 0.746279, Val_Loss:1.981163, Runtime: 62.08 seconds, Train Accurracy : 0.724187, Validation Accuracy : 0.427169
# Epoch: 30, Train Loss: 0.709996, Val_Loss:1.987857, Runtime: 62.12 seconds, Train Accurracy : 0.731530, Validation Accuracy : 0.430350
# Total Training Time: 1864.86 seconds

# %%
def get_model_size(model):
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total_params, trainable_params

# %%
total_params, trainable_params = get_model_size(model)
print(f"  Total parameters: {total_params}")
print(f"  Trainable parameters: {trainable_params}")
# Out:
#   Total parameters: 11988132
#   Trainable parameters: 11988132

# %%
torch.save(model, "saved_model.pth")
print("Full model saved as 'saved_model.pth'")


torch.save(model.state_dict(), "saved_weights.pth")
print("Model weights saved as 'saved_weights.pth'")
# Out:
# Full model saved as 'saved_model.pth'
# Model weights saved as 'saved_weights.pth'
